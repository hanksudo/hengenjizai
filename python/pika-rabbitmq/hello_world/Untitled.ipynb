# %%
# !pip2 list
# Out:
# Package                                Version     Location
# -------------------------------------- ----------- ----------------------------------
# 3to2                                   1.1.1
# agate                                  1.6.0
# agate-dbf                              0.2.0
# agate-excel                            0.2.1
# agate-sql                              0.5.2
# alabaster                              0.7.6
# altgraph                               0.12
# apipkg                                 1.4
# appdirs                                1.4.3
# appengine                              1.8.0.2
# appnope                                0.1.0
# argh                                   0.26.2
# arrow                                  0.7.0
# aspy.yaml                              0.2.1
# astroid                                1.3.8
# attrs                                  17.2.0
# Automat                                0.6.0
# autopep8                               1.2.4
# ...
